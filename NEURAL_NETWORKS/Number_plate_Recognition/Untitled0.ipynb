# %%
# Установка библиотеки ultralytics
# !pip install ultralytics

from google.colab import drive
from ultralytics import YOLO
import os

# Подключаем Google Диск
drive.mount('/content/drive')

# Путь к вашему проекту на Google Диске
project_path = '/content/drive/MyDrive/Finel_Project'

# Проверка существования директории, создание если не существует
if not os.path.exists(project_path):
    os.makedirs(project_path)

# Путь к вашему файлу данных и сохранению весов
data_path = '/content/drive/MyDrive/License_Plate_Recognition/data.yaml'
weights_path = os.path.join(project_path, 'weights')

def train_model():
    model = YOLO('yolov8s.pt')

    # Запуск процесса обучения
    model.train(
        data=data_path,
        imgsz=480,                    # Размер изображений
        epochs=100,                    # Максимальное количество эпох
        patience=5,                   # Количество эпох без улучшения для ранней остановки
        name='YOLOv8s_license_plate',  # Имя эксперимента
        project=project_path,          # Путь к проекту на Google Диске
    )

# Вызов функции для начала обучения
train_model()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 408.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.0/869.0 kB 5.0 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-c220b4e2811b> in <cell line: 9>()
#       7
#       8 # Подключаем Google Диск
# ----> 9 drive.mount('/content/drive')
#      10
#      11 # Путь к вашему проекту на Google Диске
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# ...
