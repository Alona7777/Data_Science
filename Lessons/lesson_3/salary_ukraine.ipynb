# %% [markdown]
# ### Підготовка і аналіз даних
# 1.Визначаємо загальну кількість років та місяців у даних
# 2.Визначити кількість рядків і стовпчиків
# 3.Визначити тип даних
# 4.Замінити в таблиці "—" на значення  NaN
# 5.Також заміню назви стовпців на зручні
# 6.Прибрати символи '▲' та '▼' у всіх стовпцях
# 7.Прибрати текст у квадратних дужках  всіх стовпцях
# 8.Використання регулярного виразу r'\[.*?\]' вказує на пошук будь-якого тексту,що знаходиться між квадратними дужками [ ].
# 9.Заміна ком на крапки та перетворення на числовий тип для всіх стовпців
# 10.Заповнення NaN середнім значенням стовпця
# 11.Ще раз перевіримо тип стовпців
# 12.Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum) кореляції
#
# Дані підготовлені, можна виконувати завдання.
# ### Завдання.
# 1.Для років від 2000 вивести саме ті роки, саме ті роки, коли зп була більше 4000 грн і менше 7000 грн
# 2.Видаліть  останній рядок
# 3.Відфільтрувати дані за зростанням у стовпці та вивести перший, останній та третій рядки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
source = 'https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0%D1%80%D0%BE%D0%B1%D1%96%D1%82%D0%BD%D0%B0_%D0%BF%D0%BB%D0%B0%D1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96'
df = pd.read_html(source, match="Середньорічна щомісячна зарплата в Україні з 1992 року", thousands=".", decimal=",")[0]
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 source = 'https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0%D1%80%D0%BE%D0%B1%D1%96%D1%82%D0%BD%D0%B0_%D0%BF%D0%BB%D0%B0%D1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96'
# ----> 2 df = pd.read_html(source, match="Середньорічна щомісячна зарплата в Україні з 1992 року", thousands=".", decimal=",")[0]
#       3 print(df)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
# ...

# %%
source = 'https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0[…]1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96'
df = pd.read_html(source, match="Середньорічна щомісячна зарплата в Україні з 1992 року", thousands=".", decimal=",")[0]
print(df)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[17], line 2
#       1 source = 'https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0[…]1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96'
# ----> 2 df = pd.read_html(source, match="Середньорічна щомісячна зарплата в Україні з 1992 року", thousands=".", decimal=",")[0]
#       3 print(df)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
# ...
