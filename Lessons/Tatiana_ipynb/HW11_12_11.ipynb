# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Embedding, SimpleRNN, LSTM, GRU, Bidirectional, Dense
import time

import matplotlib.pyplot as plt

# %%
NUM_WORDS = 1024*16
MAXLEN = 256
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=NUM_WORDS,
                                                      skip_top=16, # не враховувати слів найчастіших за вживаністю
                                                      seed=int(time.time()) - 10-11-2023)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
X_train = pad_sequences(X_train, maxlen=MAXLEN)
X_test = pad_sequences(X_test, maxlen=MAXLEN)

# %%
len(X_train)
# Out:
# 25000

# %%
def plot_acc_loss_history(history, title=""):
    plt.figure(figsize=(13,3))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], marker='o', label='accuracy')
    plt.plot(history.history['val_accuracy'], marker='o', label='validate accuracy')
    plt.fill_between(range(len(history.history['accuracy'])), history.history['accuracy'], history.history['val_accuracy'], alpha=0.2)
    plt.grid()
    plt.xticks(range(1, len(history.history['accuracy'])+1))
    plt.xlabel("Епоха")
    plt.ylabel("Точність")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], marker='o', label='loss')
    plt.plot(history.history['val_loss'], marker='o', label='validate loss')
    plt.fill_between(range(len(h.history['loss'])), history.history['loss'], history.history['val_loss'], alpha=0.2)
    plt.grid()
    plt.xticks(range(1, len(history.history['loss'])+1))
    plt.xlabel("Епоха")
    plt.ylabel("Втрати")
    plt.legend()

    if len(title):
        plt.suptitle(title, fontsize=20)
    plt.show()

# %% [markdown]
# # **Simple RNN**

# %%
#1
model_rnn = Sequential()
model_rnn.add(Embedding(NUM_WORDS, 32))
model_rnn.add(Dense(768, activation='relu'))
model_rnn.add(SimpleRNN(128))
model_rnn.add(Dropout(0.5))
model_rnn.add(Dense(256, activation='relu'))
model_rnn.add(Dense(1, activation='sigmoid'))
model_rnn.summary()

model_rnn.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00015, ema_momentum=1.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          524288
#
#  dense (Dense)               (None, None, 768)         25344
#
#  simple_rnn (SimpleRNN)      (None, 128)               114816
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 697729 (2.66 MB)
# Trainable params: 697729 (2.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_rnn.hdf5", verbose=1, save_best_only=True)

h = model_rnn.fit(X_train, y_train,
                  validation_data=(X_test, y_test),
                  epochs=15,
                  batch_size=256,
                  callbacks=[checkpointer])

model_rnn.load_weights("best_rnn.hdf5")

loss, accuracy = model_rnn.evaluate(X_test, y_test, verbose=0)
print('[rnn]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.5005
# Epoch 1: val_loss improved from inf to 0.69266, saving model to best_rnn.hdf5
# 98/98 [==============================] - 47s 426ms/step - loss: 0.6945 - accuracy: 0.5005 - val_loss: 0.6927 - val_accuracy: 0.5147
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 98/98 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5311
# Epoch 2: val_loss improved from 0.69266 to 0.68915, saving model to best_rnn.hdf5
# 98/98 [==============================] - 43s 436ms/step - loss: 0.6909 - accuracy: 0.5311 - val_loss: 0.6891 - val_accuracy: 0.5427
# Epoch 3/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6788 - accuracy: 0.5805
# Epoch 3: val_loss improved from 0.68915 to 0.67808, saving model to best_rnn.hdf5
# 98/98 [==============================] - 35s 363ms/step - loss: 0.6788 - accuracy: 0.5805 - val_loss: 0.6781 - val_accuracy: 0.5971
# Epoch 4/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.6722
# Epoch 4: val_loss improved from 0.67808 to 0.46293, saving model to best_rnn.hdf5
# 98/98 [==============================] - 32s 328ms/step - loss: 0.6306 - accuracy: 0.6722 - val_loss: 0.4629 - val_accuracy: 0.7913
# Epoch 5/15
# 98/98 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.8144
# Epoch 5: val_loss improved from 0.46293 to 0.37411, saving model to best_rnn.hdf5
# 98/98 [==============================] - 35s 358ms/step - loss: 0.4227 - accuracy: 0.8144 - val_loss: 0.3741 - val_accuracy: 0.8343
# Epoch 6/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8819
# Epoch 6: val_loss improved from 0.37411 to 0.34228, saving model to best_rnn.hdf5
# 98/98 [==============================] - 31s 320ms/step - loss: 0.2901 - accuracy: 0.8819 - val_loss: 0.3423 - val_accuracy: 0.8538
# Epoch 7/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2141 - accuracy: 0.9202
# Epoch 7: val_loss did not improve from 0.34228
# 98/98 [==============================] - 32s 327ms/step - loss: 0.2141 - accuracy: 0.9202 - val_loss: 0.3529 - val_accuracy: 0.8552
# Epoch 8/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9450
# Epoch 8: val_loss did not improve from 0.34228
# 98/98 [==============================] - 30s 310ms/step - loss: 0.1581 - accuracy: 0.9450 - val_loss: 0.3616 - val_accuracy: 0.8634
# Epoch 9/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9580
# Epoch 9: val_loss did not improve from 0.34228
# 98/98 [==============================] - 28s 289ms/step - loss: 0.1246 - accuracy: 0.9580 - val_loss: 0.4204 - val_accuracy: 0.8383
# Epoch 10/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9658
# Epoch 10: val_loss did not improve from 0.34228
# 98/98 [==============================] - 30s 304ms/step - loss: 0.1031 - accuracy: 0.9658 - val_loss: 0.4164 - val_accuracy: 0.8621
# Epoch 11/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9792
# Epoch 11: val_loss did not improve from 0.34228
# 98/98 [==============================] - 29s 294ms/step - loss: 0.0702 - accuracy: 0.9792 - val_loss: 0.4534 - val_accuracy: 0.8551
# Epoch 12/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9860
# Epoch 12: val_loss did not improve from 0.34228
# 98/98 [==============================] - 28s 282ms/step - loss: 0.0485 - accuracy: 0.9860 - val_loss: 0.5079 - val_accuracy: 0.8587
# Epoch 13/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9924
# Epoch 13: val_loss did not improve from 0.34228
# 98/98 [==============================] - 28s 285ms/step - loss: 0.0297 - accuracy: 0.9924 - val_loss: 0.5660 - val_accuracy: 0.8467
# Epoch 14/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9934
# Epoch 14: val_loss did not improve from 0.34228
# 98/98 [==============================] - 27s 276ms/step - loss: 0.0255 - accuracy: 0.9934 - val_loss: 0.5980 - val_accuracy: 0.8442
# Epoch 15/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9930
# Epoch 15: val_loss did not improve from 0.34228
# 98/98 [==============================] - 28s 280ms/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.6598 - val_accuracy: 0.8502
# [rnn]	 Test Accuracy: 85.38%

# %%
plot_acc_loss_history(h, "Simple RNN")

# %% [markdown]
# ## Примітка
#
# Початковій SimpleRNN моделі без додаткових шарів було характерно на перших кроках швидке навчання максимум до 84% з подальшим спадом менше 80% - відбувалося перенавчання. Шоб побороти це в дейтасеті ігнорувалися слова, що входять у 16 найуживаніших, та був доданий повнозв'язний шір між входом та SimpleRNN шаром та повнозв'язний шар після. Також шар Dropout допоміг зменшити ефект перенавчання, а підібрані гіперпараметри дозволили оптимізувати градієнтний спуск. Саме в такій комбінації досяглася максимальна точність при мінімумі помилок, але перенавчання все одно швидко настає.
#
# **Фактично, SimpleRNN шар навчається не на вхідних даних, а на автовиявлених ознаках входу!** Це цікавий ефект, що потребує додаткового дослідження.

# %% [markdown]
# # **LSTM**

# %%
model_lstm = Sequential()
model_lstm.add(Embedding(NUM_WORDS, 32))
model_lstm.add(Dense(768, activation='relu'))
model_lstm.add(LSTM(128))
model_lstm.add(Dropout(0.5))
model_lstm.add(Dense(512, activation='relu'))
model_lstm.add(Dense(1, activation='sigmoid'))
model_lstm.summary()

model_lstm.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003, ema_momentum=1.9),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 32)          524288
#
#  dense_3 (Dense)             (None, None, 768)         25344
#
#  lstm (LSTM)                 (None, 128)               459264
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 512)               66048
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1075457 (4.10 MB)
# Trainable params: 1075457 (4.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_lstm.hdf5", verbose=1, save_best_only=True)

h = model_lstm.fit(X_train, y_train,
                   validation_data=(X_test, y_test),
                   epochs=15,
                   batch_size=256,
                   callbacks=[checkpointer])

model_lstm.load_weights("best_lstm.hdf5")

loss, accuracy = model_lstm.evaluate(X_test, y_test, verbose=1)
print('[lstm]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.5873
# Epoch 1: val_loss improved from inf to 0.57527, saving model to best_lstm.hdf5
# 98/98 [==============================] - 19s 169ms/step - loss: 0.6747 - accuracy: 0.5873 - val_loss: 0.5753 - val_accuracy: 0.7290
# Epoch 2/15
# 98/98 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8388
# Epoch 2: val_loss improved from 0.57527 to 0.33780, saving model to best_lstm.hdf5
# 98/98 [==============================] - 15s 153ms/step - loss: 0.3744 - accuracy: 0.8388 - val_loss: 0.3378 - val_accuracy: 0.8554
# Epoch 3/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9156
# Epoch 3: val_loss improved from 0.33780 to 0.29638, saving model to best_lstm.hdf5
# 98/98 [==============================] - 14s 139ms/step - loss: 0.2219 - accuracy: 0.9156 - val_loss: 0.2964 - val_accuracy: 0.8792
# Epoch 4/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9436
# Epoch 4: val_loss did not improve from 0.29638
# 98/98 [==============================] - 13s 132ms/step - loss: 0.1583 - accuracy: 0.9436 - val_loss: 0.3342 - val_accuracy: 0.8780
# Epoch 5/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9584
# Epoch 5: val_loss did not improve from 0.29638
# 98/98 [==============================] - 13s 134ms/step - loss: 0.1255 - accuracy: 0.9584 - val_loss: 0.4025 - val_accuracy: 0.8622
# Epoch 6/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9681
# Epoch 6: val_loss did not improve from 0.29638
# 98/98 [==============================] - 13s 133ms/step - loss: 0.0974 - accuracy: 0.9681 - val_loss: 0.4114 - val_accuracy: 0.8648
# Epoch 7/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9734
# Epoch 7: val_loss did not improve from 0.29638
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0849 - accuracy: 0.9734 - val_loss: 0.4589 - val_accuracy: 0.8614
# Epoch 8/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9839
# Epoch 8: val_loss did not improve from 0.29638
# 98/98 [==============================] - 12s 127ms/step - loss: 0.0580 - accuracy: 0.9839 - val_loss: 0.5077 - val_accuracy: 0.8536
# Epoch 9/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9881
# Epoch 9: val_loss did not improve from 0.29638
# 98/98 [==============================] - 11s 117ms/step - loss: 0.0448 - accuracy: 0.9881 - val_loss: 0.5901 - val_accuracy: 0.8537
# Epoch 10/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9891
# Epoch 10: val_loss did not improve from 0.29638
# 98/98 [==============================] - 14s 139ms/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.7576 - val_accuracy: 0.8483
# Epoch 11/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9910
# Epoch 11: val_loss did not improve from 0.29638
# 98/98 [==============================] - 12s 120ms/step - loss: 0.0332 - accuracy: 0.9910 - val_loss: 0.7024 - val_accuracy: 0.8477
# Epoch 12/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9910
# Epoch 12: val_loss did not improve from 0.29638
# 98/98 [==============================] - 11s 116ms/step - loss: 0.0317 - accuracy: 0.9910 - val_loss: 0.8309 - val_accuracy: 0.8396
# Epoch 13/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9875
# Epoch 13: val_loss did not improve from 0.29638
# 98/98 [==============================] - 13s 135ms/step - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.9028 - val_accuracy: 0.8440
# Epoch 14/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9929
# Epoch 14: val_loss did not improve from 0.29638
# 98/98 [==============================] - 13s 137ms/step - loss: 0.0242 - accuracy: 0.9929 - val_loss: 0.8341 - val_accuracy: 0.8422
# Epoch 15/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9908
# Epoch 15: val_loss did not improve from 0.29638
# 98/98 [==============================] - 12s 118ms/step - loss: 0.0282 - accuracy: 0.9908 - val_loss: 0.8229 - val_accuracy: 0.8388
# 782/782 [==============================] - 6s 8ms/step - loss: 0.2964 - accuracy: 0.8792
# [lstm]	 Test Accuracy: 87.92%

# %%
plot_acc_loss_history(h, "LSTM")

# %% [markdown]
# # **Bidirectional**

# %%
model_bdlstm = Sequential()
model_bdlstm.add(Embedding(NUM_WORDS,54))
model_bdlstm.add(Bidirectional(LSTM(64)))
model_bdlstm.add(Dense(1, activation='sigmoid'))
model_bdlstm.summary()

# model_bdlstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_bdlstm.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003, ema_momentum=1.9),
                     loss='binary_crossentropy',
                     metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 54)          884736
#
#  bidirectional (Bidirection  (None, 128)               60928
#  al)
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 945793 (3.61 MB)
# Trainable params: 945793 (3.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_bdlstm.hdf5", verbose=1, save_best_only=True)

h = model_bdlstm.fit(X_train, y_train,
                   validation_data=(X_test, y_test),
                   epochs=15,
                   batch_size=256,
                   callbacks=[checkpointer])

model_bdlstm.load_weights("best_bdlstm.hdf5")

loss, accuracy = model_bdlstm.evaluate(X_test, y_test, verbose=1)
print('[bdlstm]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.6029
# Epoch 1: val_loss improved from inf to 0.54009, saving model to best_bdlstm.hdf5
# 98/98 [==============================] - 23s 207ms/step - loss: 0.6615 - accuracy: 0.6029 - val_loss: 0.5401 - val_accuracy: 0.7567
# Epoch 2/15
# 98/98 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8500
# Epoch 2: val_loss improved from 0.54009 to 0.36449, saving model to best_bdlstm.hdf5
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4015 - accuracy: 0.8500 - val_loss: 0.3645 - val_accuracy: 0.8670
# Epoch 3/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9064
# Epoch 3: val_loss improved from 0.36449 to 0.34964, saving model to best_bdlstm.hdf5
# 98/98 [==============================] - 14s 146ms/step - loss: 0.2812 - accuracy: 0.9064 - val_loss: 0.3496 - val_accuracy: 0.8614
# Epoch 4/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9290
# Epoch 4: val_loss improved from 0.34964 to 0.31428, saving model to best_bdlstm.hdf5
# 98/98 [==============================] - 11s 116ms/step - loss: 0.2187 - accuracy: 0.9290 - val_loss: 0.3143 - val_accuracy: 0.8740
# Epoch 5/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9422
# Epoch 5: val_loss did not improve from 0.31428
# 98/98 [==============================] - 11s 113ms/step - loss: 0.1789 - accuracy: 0.9422 - val_loss: 0.3192 - val_accuracy: 0.8722
# Epoch 6/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9555
# Epoch 6: val_loss did not improve from 0.31428
# 98/98 [==============================] - 8s 85ms/step - loss: 0.1415 - accuracy: 0.9555 - val_loss: 0.3566 - val_accuracy: 0.8627
# Epoch 7/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9639
# Epoch 7: val_loss did not improve from 0.31428
# 98/98 [==============================] - 7s 71ms/step - loss: 0.1178 - accuracy: 0.9639 - val_loss: 0.4403 - val_accuracy: 0.8478
# Epoch 8/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9686
# Epoch 8: val_loss did not improve from 0.31428
# 98/98 [==============================] - 8s 86ms/step - loss: 0.1037 - accuracy: 0.9686 - val_loss: 0.3864 - val_accuracy: 0.8530
# Epoch 9/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9758
# Epoch 9: val_loss did not improve from 0.31428
# 98/98 [==============================] - 7s 66ms/step - loss: 0.0854 - accuracy: 0.9758 - val_loss: 0.4825 - val_accuracy: 0.8424
# Epoch 10/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9812
# Epoch 10: val_loss did not improve from 0.31428
# 98/98 [==============================] - 7s 74ms/step - loss: 0.0720 - accuracy: 0.9812 - val_loss: 0.4607 - val_accuracy: 0.8486
# Epoch 11/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9856
# Epoch 11: val_loss did not improve from 0.31428
# 98/98 [==============================] - 6s 58ms/step - loss: 0.0600 - accuracy: 0.9856 - val_loss: 0.4860 - val_accuracy: 0.8448
# Epoch 12/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9868
# Epoch 12: val_loss did not improve from 0.31428
# 98/98 [==============================] - 5s 49ms/step - loss: 0.0550 - accuracy: 0.9868 - val_loss: 0.5748 - val_accuracy: 0.8363
# Epoch 13/15
# 96/98 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9887
# Epoch 13: val_loss did not improve from 0.31428
# 98/98 [==============================] - 5s 53ms/step - loss: 0.0497 - accuracy: 0.9887 - val_loss: 0.4938 - val_accuracy: 0.8430
# Epoch 14/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9873
# Epoch 14: val_loss did not improve from 0.31428
# 98/98 [==============================] - 7s 67ms/step - loss: 0.0514 - accuracy: 0.9873 - val_loss: 0.5858 - val_accuracy: 0.8356
# Epoch 15/15
# 98/98 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9915
# Epoch 15: val_loss did not improve from 0.31428
# 98/98 [==============================] - 4s 46ms/step - loss: 0.0398 - accuracy: 0.9915 - val_loss: 0.6313 - val_accuracy: 0.8316
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3143 - accuracy: 0.8740
# [bdlstm]	 Test Accuracy: 87.40%

# %%
plot_acc_loss_history(h, "Bidirectional LSTM")

# %%
model_bdrnn = Sequential()
model_bdrnn.add(Embedding(NUM_WORDS, 32))
model_bdrnn.add(Bidirectional(SimpleRNN(64)))
model_bdrnn.add(Dropout(0.75))
# model_bdrnn.add(Dense(256, activation='relu'))
model_bdrnn.add(Dense(1, activation='sigmoid'))
model_bdrnn.summary()

model_bdrnn.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00015, ema_momentum=1.9),
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_25 (Embedding)    (None, None, 32)          524288
#
#  bidirectional_7 (Bidirecti  (None, 128)               12416
#  onal)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_48 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 536833 (2.05 MB)
# Trainable params: 536833 (2.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_bdrnn = Sequential()
model_bdrnn.add(Embedding(NUM_WORDS, 32))
model_bdrnn.add(Dense(768, activation='relu'))
model_bdrnn.add(Bidirectional(SimpleRNN(64)))
model_bdrnn.add(Dropout(0.5))
model_bdrnn.add(Dense(256, activation='relu'))
model_bdrnn.add(Dense(1, activation='sigmoid'))
model_bdrnn.summary()

model_bdrnn.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00015, ema_momentum=1.9),
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, None, 32)          35552
#
#  dense_15 (Dense)            (None, None, 768)         25344
#
#  bidirectional_3 (Bidirecti  (None, 128)               106624
#  onal)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 256)               33024
#
#  dense_17 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 200801 (784.38 KB)
# Trainable params: 200801 (784.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_bdrnn.hdf5", verbose=1, save_best_only=True)

h = model_bdrnn.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=15,
                    batch_size=256,
                    callbacks=[checkpointer])

model_bdrnn.load_weights("best_bdrnn.hdf5")

loss, accuracy = model_bdrnn.evaluate(X_test, y_test, verbose=1)
print('[bdrnn]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6992 - accuracy: 0.5117
# Epoch 1: val_loss improved from inf to 0.68565, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 141s 1s/step - loss: 0.6992 - accuracy: 0.5117 - val_loss: 0.6857 - val_accuracy: 0.5502
# Epoch 2/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6777 - accuracy: 0.5695
# Epoch 2: val_loss improved from 0.68565 to 0.67689, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 142s 1s/step - loss: 0.6777 - accuracy: 0.5695 - val_loss: 0.6769 - val_accuracy: 0.5862
# Epoch 3/15
# 98/98 [==============================] - ETA: 0s - loss: 0.6348 - accuracy: 0.6616
# Epoch 3: val_loss improved from 0.67689 to 0.61592, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 137s 1s/step - loss: 0.6348 - accuracy: 0.6616 - val_loss: 0.6159 - val_accuracy: 0.6864
# Epoch 4/15
# 98/98 [==============================] - ETA: 0s - loss: 0.5382 - accuracy: 0.7703
# Epoch 4: val_loss improved from 0.61592 to 0.56118, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 130s 1s/step - loss: 0.5382 - accuracy: 0.7703 - val_loss: 0.5612 - val_accuracy: 0.7163
# Epoch 5/15
# 98/98 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.8182
# Epoch 5: val_loss improved from 0.56118 to 0.43238, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 131s 1s/step - loss: 0.4617 - accuracy: 0.8182 - val_loss: 0.4324 - val_accuracy: 0.8210
# Epoch 6/15
# 98/98 [==============================] - ETA: 0s - loss: 0.3800 - accuracy: 0.8632
# Epoch 6: val_loss improved from 0.43238 to 0.40684, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 130s 1s/step - loss: 0.3800 - accuracy: 0.8632 - val_loss: 0.4068 - val_accuracy: 0.8249
# Epoch 7/15
# 98/98 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8796
# Epoch 7: val_loss improved from 0.40684 to 0.37518, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 130s 1s/step - loss: 0.3446 - accuracy: 0.8796 - val_loss: 0.3752 - val_accuracy: 0.8426
# Epoch 8/15
# 98/98 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8941
# Epoch 8: val_loss improved from 0.37518 to 0.35875, saving model to best_bdrnn.hdf5
# 98/98 [==============================] - 130s 1s/step - loss: 0.3034 - accuracy: 0.8941 - val_loss: 0.3588 - val_accuracy: 0.8493
# Epoch 9/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.9124
# Epoch 9: val_loss did not improve from 0.35875
# 98/98 [==============================] - 131s 1s/step - loss: 0.2690 - accuracy: 0.9124 - val_loss: 0.3664 - val_accuracy: 0.8507
# Epoch 10/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.9236
# Epoch 10: val_loss did not improve from 0.35875
# 98/98 [==============================] - 130s 1s/step - loss: 0.2421 - accuracy: 0.9236 - val_loss: 0.3694 - val_accuracy: 0.8385
# Epoch 11/15
# 98/98 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9318
# Epoch 11: val_loss did not improve from 0.35875
# 98/98 [==============================] - 130s 1s/step - loss: 0.2206 - accuracy: 0.9318 - val_loss: 0.3593 - val_accuracy: 0.8559
# Epoch 12/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9452
# Epoch 12: val_loss did not improve from 0.35875
# 98/98 [==============================] - 130s 1s/step - loss: 0.1888 - accuracy: 0.9452 - val_loss: 0.3709 - val_accuracy: 0.8545
# Epoch 13/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9516
# Epoch 13: val_loss did not improve from 0.35875
# 98/98 [==============================] - 130s 1s/step - loss: 0.1711 - accuracy: 0.9516 - val_loss: 0.4304 - val_accuracy: 0.8501
# Epoch 14/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9553
# Epoch 14: val_loss did not improve from 0.35875
# 98/98 [==============================] - 130s 1s/step - loss: 0.1615 - accuracy: 0.9553 - val_loss: 0.4058 - val_accuracy: 0.8364
# Epoch 15/15
# 98/98 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9632
# Epoch 15: val_loss did not improve from 0.35875
# 98/98 [==============================] - 129s 1s/step - loss: 0.1403 - accuracy: 0.9632 - val_loss: 0.4464 - val_accuracy: 0.8506
# 782/782 [==============================] - 36s 46ms/step - loss: 0.3588 - accuracy: 0.8493
# [bdrnn] Test Accuracy: 84.93%

# %%
plot_acc_loss_history(h, "Bidirectional SimpleRNN")

# %% [markdown]
# return_sequences=True

# %% [markdown]
# ## Примітка
#
# Складається враження, що двунаправлені нейромережі не підходять для задачі, схожій на сентимент-аналіз, оскільки "читання" речень у зворотньому порядку не дають нової інформації для передбачення.

# %% [markdown]
# # **Глибокі (deep) нейромережі**

# %%
model_dprnn = Sequential()
model_dprnn.add(Embedding(NUM_WORDS, 32))
model_dprnn.add(SimpleRNN(128, return_sequences=True))
# model_dprnn.add(Dropout(0.5))
model_dprnn.add(SimpleRNN(64))
model_dprnn.add(Dense(1, activation='sigmoid'))
model_dprnn.summary()

model_dprnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_36 (Embedding)    (None, None, 32)          524288
#
#  simple_rnn_19 (SimpleRNN)   (None, None, 128)         20608
#
#  simple_rnn_20 (SimpleRNN)   (None, 64)                12352
#
#  dense_58 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 557313 (2.13 MB)
# Trainable params: 557313 (2.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_dprnn.hdf5", verbose=1, save_best_only=True)

h = model_dprnn.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=10,
                    batch_size=64,
                    callbacks=[checkpointer])

model_dprnn.load_weights("best_dprnn.hdf5")

loss, accuracy = model_dprnn.evaluate(X_test, y_test, verbose=1)
print('[dprnn]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/10
# 391/391 [==============================] - ETA: 0s - loss: 0.6736 - accuracy: 0.5538
# Epoch 1: val_loss improved from inf to 0.62019, saving model to best_dprnn.hdf5
# 391/391 [==============================] - 262s 664ms/step - loss: 0.6736 - accuracy: 0.5538 - val_loss: 0.6202 - val_accuracy: 0.6372
# Epoch 2/10
# 391/391 [==============================] - ETA: 0s - loss: 0.5763 - accuracy: 0.6961
# Epoch 2: val_loss improved from 0.62019 to 0.53712, saving model to best_dprnn.hdf5
# 391/391 [==============================] - 257s 657ms/step - loss: 0.5763 - accuracy: 0.6961 - val_loss: 0.5371 - val_accuracy: 0.7272
# Epoch 3/10
# 391/391 [==============================] - ETA: 0s - loss: 0.4462 - accuracy: 0.7992
# Epoch 3: val_loss improved from 0.53712 to 0.46250, saving model to best_dprnn.hdf5
# 391/391 [==============================] - 249s 636ms/step - loss: 0.4462 - accuracy: 0.7992 - val_loss: 0.4625 - val_accuracy: 0.8076
# Epoch 4/10
# 391/391 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8024
# Epoch 4: val_loss did not improve from 0.46250
# 391/391 [==============================] - 249s 638ms/step - loss: 0.4315 - accuracy: 0.8024 - val_loss: 0.5078 - val_accuracy: 0.7707
# Epoch 5/10
# 391/391 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8353
# Epoch 5: val_loss did not improve from 0.46250
# 391/391 [==============================] - 252s 645ms/step - loss: 0.3776 - accuracy: 0.8353 - val_loss: 0.4701 - val_accuracy: 0.7976
# Epoch 6/10
# 391/391 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8807
# Epoch 6: val_loss did not improve from 0.46250
# 391/391 [==============================] - 254s 650ms/step - loss: 0.3000 - accuracy: 0.8807 - val_loss: 0.4691 - val_accuracy: 0.8150
# Epoch 7/10
# 391/391 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.9148
# Epoch 7: val_loss did not improve from 0.46250
# 391/391 [==============================] - 255s 653ms/step - loss: 0.2264 - accuracy: 0.9148 - val_loss: 0.5184 - val_accuracy: 0.7637
# Epoch 8/10
# 391/391 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.7893
# Epoch 8: val_loss did not improve from 0.46250
# 391/391 [==============================] - 250s 641ms/step - loss: 0.4760 - accuracy: 0.7893 - val_loss: 0.5378 - val_accuracy: 0.7680
# Epoch 9/10
# 391/391 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.8931
# Epoch 9: val_loss did not improve from 0.46250
# 391/391 [==============================] - 250s 639ms/step - loss: 0.2684 - accuracy: 0.8931 - val_loss: 0.5157 - val_accuracy: 0.8044
# Epoch 10/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9407
# Epoch 10: val_loss did not improve from 0.46250
# 391/391 [==============================] - 252s 645ms/step - loss: 0.1688 - accuracy: 0.9407 - val_loss: 0.5320 - val_accuracy: 0.7894
# 782/782 [==============================] - 51s 65ms/step - loss: 0.4625 - accuracy: 0.8076
# [dprnn]	 Test Accuracy: 80.76%

# %%
plot_acc_loss_history(h, "Deep SimpleRNN")

# %%
model_dpgru = Sequential()
model_dpgru.add(Embedding(NUM_WORDS, 32))
model_dpgru.add(GRU(128, return_sequences=True))
model_dpgru.add(Dropout(0.9))
model_dpgru.add(GRU(64))
model_dpgru.add(Dense(1, activation='sigmoid'))
model_dpgru.summary()

model_dpgru.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_32 (Embedding)    (None, None, 32)          524288
#
#  gru_4 (GRU)                 (None, None, 128)         62208
#
#  dropout_23 (Dropout)        (None, None, 128)         0
#
#  gru_5 (GRU)                 (None, 64)                37248
#
#  dense_54 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 623809 (2.38 MB)
# Trainable params: 623809 (2.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_dpgru.hdf5", verbose=1, save_best_only=True)

h = model_dpgru.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=10,
                    batch_size=64,
                    callbacks=[checkpointer])

model_dpgru.load_weights("best_dpgru.hdf5")

loss, accuracy = model_dpgru.evaluate(X_test, y_test, verbose=1)
print('[dpgru]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/10
# 391/391 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.7258
# Epoch 1: val_loss improved from inf to 0.39392, saving model to best_dpgru.hdf5
# 391/391 [==============================] - 782s 2s/step - loss: 0.5217 - accuracy: 0.7258 - val_loss: 0.3939 - val_accuracy: 0.8354
# Epoch 2/10
# 391/391 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.8880
# Epoch 2: val_loss improved from 0.39392 to 0.35128, saving model to best_dpgru.hdf5
# 391/391 [==============================] - 794s 2s/step - loss: 0.2811 - accuracy: 0.8880 - val_loss: 0.3513 - val_accuracy: 0.8574
# Epoch 3/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9319
# Epoch 3: val_loss improved from 0.35128 to 0.34589, saving model to best_dpgru.hdf5
# 391/391 [==============================] - 808s 2s/step - loss: 0.1849 - accuracy: 0.9319 - val_loss: 0.3459 - val_accuracy: 0.8612
# Epoch 4/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9524
# Epoch 4: val_loss did not improve from 0.34589
# 391/391 [==============================] - 855s 2s/step - loss: 0.1385 - accuracy: 0.9524 - val_loss: 0.3969 - val_accuracy: 0.8608
# Epoch 5/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9673
# Epoch 5: val_loss did not improve from 0.34589
# 391/391 [==============================] - 893s 2s/step - loss: 0.0970 - accuracy: 0.9673 - val_loss: 0.4535 - val_accuracy: 0.8513
# Epoch 6/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9773
# Epoch 6: val_loss did not improve from 0.34589
# 391/391 [==============================] - 936s 2s/step - loss: 0.0730 - accuracy: 0.9773 - val_loss: 0.4828 - val_accuracy: 0.8554
# Epoch 7/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9862
# Epoch 7: val_loss did not improve from 0.34589
# 391/391 [==============================] - 913s 2s/step - loss: 0.0474 - accuracy: 0.9862 - val_loss: 0.5508 - val_accuracy: 0.8523
# Epoch 8/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9888
# Epoch 8: val_loss did not improve from 0.34589
# 391/391 [==============================] - 888s 2s/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.6544 - val_accuracy: 0.8470
# Epoch 9/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9919
# Epoch 9: val_loss did not improve from 0.34589
# 391/391 [==============================] - 879s 2s/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 0.6484 - val_accuracy: 0.8459
# Epoch 10/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9929
# Epoch 10: val_loss did not improve from 0.34589
# 391/391 [==============================] - 857s 2s/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 0.6748 - val_accuracy: 0.8437
# 782/782 [==============================] - 122s 156ms/step - loss: 0.3459 - accuracy: 0.8612
# [dplstm]	 Test Accuracy: 86.12%

# %%
plot_acc_loss_history(h, "Deep GRU")

# %%
model_dplstm = Sequential()
model_dplstm.add(Embedding(NUM_WORDS, 32))
model_dplstm.add(LSTM(128, return_sequences=True))
model_dplstm.add(Dropout(0.5))
model_dplstm.add(LSTM(64))
model_dplstm.add(Dense(1, activation='sigmoid'))
model_dplstm.summary()

model_dplstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_28 (Embedding)    (None, None, 32)          524288
#
#  lstm_14 (LSTM)              (None, None, 128)         82432
#
#  dropout_20 (Dropout)        (None, None, 128)         0
#
#  lstm_15 (LSTM)              (None, 64)                49408
#
#  dense_51 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 656193 (2.50 MB)
# Trainable params: 656193 (2.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_dplstm.hdf5", verbose=1, save_best_only=True)

h = model_dplstm.fit(X_train, y_train,
                     validation_data=(X_test, y_test),
                     epochs=10,
                     batch_size=64,
                     callbacks=[checkpointer])

model_dplstm.load_weights("best_dplstm.hdf5")

loss, accuracy = model_dplstm.evaluate(X_test, y_test, verbose=1)
print('[dplstm]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/10
# 391/391 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.7847
# Epoch 1: val_loss improved from inf to 0.36771, saving model to best_dplstm.hdf5
# 391/391 [==============================] - 1085s 3s/step - loss: 0.4443 - accuracy: 0.7847 - val_loss: 0.3677 - val_accuracy: 0.8450
# Epoch 2/10
# 391/391 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9048
# Epoch 2: val_loss improved from 0.36771 to 0.34629, saving model to best_dplstm.hdf5
# 391/391 [==============================] - 1178s 3s/step - loss: 0.2475 - accuracy: 0.9048 - val_loss: 0.3463 - val_accuracy: 0.8658
# Epoch 3/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9384
# Epoch 3: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1173s 3s/step - loss: 0.1714 - accuracy: 0.9384 - val_loss: 0.3783 - val_accuracy: 0.8652
# Epoch 4/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9561
# Epoch 4: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1110s 3s/step - loss: 0.1255 - accuracy: 0.9561 - val_loss: 0.3791 - val_accuracy: 0.8558
# Epoch 5/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9757
# Epoch 5: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1098s 3s/step - loss: 0.0750 - accuracy: 0.9757 - val_loss: 0.4775 - val_accuracy: 0.8588
# Epoch 6/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9806
# Epoch 6: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1099s 3s/step - loss: 0.0577 - accuracy: 0.9806 - val_loss: 0.5946 - val_accuracy: 0.8514
# Epoch 7/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9812
# Epoch 7: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1109s 3s/step - loss: 0.0581 - accuracy: 0.9812 - val_loss: 0.5782 - val_accuracy: 0.8540
# Epoch 8/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9864
# Epoch 8: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1114s 3s/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.5830 - val_accuracy: 0.8376
# Epoch 9/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9869
# Epoch 9: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1100s 3s/step - loss: 0.0397 - accuracy: 0.9869 - val_loss: 0.6504 - val_accuracy: 0.8438
# Epoch 10/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9921
# Epoch 10: val_loss did not improve from 0.34629
# 391/391 [==============================] - 1130s 3s/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.7132 - val_accuracy: 0.8385
# 782/782 [==============================] - 184s 236ms/step - loss: 0.3463 - accuracy: 0.8658
# [dplstm]	 Test Accuracy: 86.58%

# %%
plot_acc_loss_history(h, "Deep LSTM")

# %%
model_dbrnn = Sequential()
model_dbrnn.add(Embedding(NUM_WORDS, 32))
model_dbrnn.add(SimpleRNN(128, return_sequences=True))
model_dbrnn.add(Bidirectional(SimpleRNN(64)))
model_dbrnn.add(Dropout(0.5))
model_dbrnn.add(Dense(256, activation='relu'))
model_dbrnn.add(Dense(1, activation='sigmoid'))
model_dbrnn.summary()

model_dbrnn.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00015, ema_momentum=1.9),
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_38 (Embedding)    (None, None, 32)          524288
#
#  simple_rnn_23 (SimpleRNN)   (None, None, 128)         20608
#
#  bidirectional_9 (Bidirecti  (None, 128)               24704
#  onal)
#
#  dropout_28 (Dropout)        (None, 128)               0
#
#  dense_61 (Dense)            (None, 256)               33024
#
#  dense_62 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 602881 (2.30 MB)
# Trainable params: 602881 (2.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath="best_dbrnn.hdf5", verbose=1, save_best_only=True)

h = model_dbrnn.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=10,
                    batch_size=64,
                    callbacks=[checkpointer])

model_dbrnn.load_weights("best_dbrnn.hdf5")

loss, accuracy = model_dbrnn.evaluate(X_test, y_test, verbose=1)
print('[dbrnn]\t Test Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Epoch 1/10
# 391/391 [==============================] - ETA: 0s - loss: 0.6984 - accuracy: 0.5064
# Epoch 1: val_loss improved from inf to 0.69437, saving model to best_dbrnn.hdf5
# 391/391 [==============================] - 396s 987ms/step - loss: 0.6984 - accuracy: 0.5064 - val_loss: 0.6944 - val_accuracy: 0.5080
# Epoch 2/10
# 391/391 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.5326
# Epoch 2: val_loss improved from 0.69437 to 0.68195, saving model to best_dbrnn.hdf5
# 391/391 [==============================] - 383s 981ms/step - loss: 0.6892 - accuracy: 0.5326 - val_loss: 0.6820 - val_accuracy: 0.5506
# Epoch 3/10
# 391/391 [==============================] - ETA: 0s - loss: 0.5698 - accuracy: 0.6988
# Epoch 3: val_loss improved from 0.68195 to 0.39450, saving model to best_dbrnn.hdf5
# 391/391 [==============================] - 382s 978ms/step - loss: 0.5698 - accuracy: 0.6988 - val_loss: 0.3945 - val_accuracy: 0.8310
# Epoch 4/10
# 391/391 [==============================] - ETA: 0s - loss: 0.3256 - accuracy: 0.8692
# Epoch 4: val_loss improved from 0.39450 to 0.34690, saving model to best_dbrnn.hdf5
# 391/391 [==============================] - 381s 975ms/step - loss: 0.3256 - accuracy: 0.8692 - val_loss: 0.3469 - val_accuracy: 0.8504
# Epoch 5/10
# 391/391 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.9059
# Epoch 5: val_loss did not improve from 0.34690
# 391/391 [==============================] - 381s 976ms/step - loss: 0.2495 - accuracy: 0.9059 - val_loss: 0.3606 - val_accuracy: 0.8547
# Epoch 6/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9317
# Epoch 6: val_loss did not improve from 0.34690
# 391/391 [==============================] - 381s 974ms/step - loss: 0.1912 - accuracy: 0.9317 - val_loss: 0.3821 - val_accuracy: 0.8395
# Epoch 7/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9477
# Epoch 7: val_loss did not improve from 0.34690
# 391/391 [==============================] - 448s 1s/step - loss: 0.1538 - accuracy: 0.9477 - val_loss: 0.4002 - val_accuracy: 0.8607
# Epoch 8/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9440
# Epoch 8: val_loss did not improve from 0.34690
# 391/391 [==============================] - 411s 1s/step - loss: 0.1538 - accuracy: 0.9440 - val_loss: 0.4383 - val_accuracy: 0.8263
# Epoch 9/10
# 391/391 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9490
# Epoch 9: val_loss did not improve from 0.34690
# 391/391 [==============================] - 395s 1s/step - loss: 0.1434 - accuracy: 0.9490 - val_loss: 0.4681 - val_accuracy: 0.8436
# Epoch 10/10
# 391/391 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9726
# Epoch 10: val_loss did not improve from 0.34690
# 391/391 [==============================] - 402s 1s/step - loss: 0.0880 - accuracy: 0.9726 - val_loss: 0.5039 - val_accuracy: 0.8410
# 782/782 [==============================] - 51s 65ms/step - loss: 0.3469 - accuracy: 0.8504
# [dbrnn]	 Test Accuracy: 85.04%

# %%
plot_acc_loss_history(h, "Deep bidirectional SimpleRNN")

# %% [markdown]
# # **Висновок:**
#
# Відсортовані результати:
# 1. [lstm]	 Test Accuracy: 87.25%
# 2. [bdlstm]  Test Accuracy: 87.21%
# 3. [dplstm]  Test Accuracy: 86.58%
# 4. [dpgru]	 Test Accuracy: 86.12%
# 5. [rnn]	 Test Accuracy: 85.66%
# 6. [dbrnn]	 Test Accuracy: 85.04%
# 7. [bdrnn]	 Test Accuracy: 84.93%
# 8. [dprnn]	 Test Accuracy: 80.76%
#
# Відсортовані результати показують, що найбільше значення має архітектура мережі, а саме LSTM. Для LSTM орієнтована пам'ятати важливе і забувати другорядне.
#
# Даній задачі характерно швидке навчання, після чого йде перенавчання. Додаткові повнозв'язні шари та шари Dropout та корегування гіперпараметрів не сильно допомогають в боротьбі з цим ефектом. Тільки зменшення MAX_WORDS реально допомогає зменшити ефект перенавчання при певному зниженні точності. В принципі - швидке навчання - це не настільки й погано, оскільки економить час.
#
# Двосторонні нейромережі очікувано показали, що вони позитивно не впливають на результат, оскільки більше орієентовані на врахування апостеріорне оточення для передбачення, а не для кінцевого висновку на всьому вхідному тексті.
